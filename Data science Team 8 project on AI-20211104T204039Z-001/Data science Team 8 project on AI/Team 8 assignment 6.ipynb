# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
import pandas as pd
import seaborn                                                                                                                                                                       as sns

# %% [markdown]
# #importing sps

# %%
skill_penetration = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Team 8 project/AI.xlsx', sheet_name='Skill Penetration')

# %%
skill_penetration.info()
skill_penetration.set_index('skill_group_name', inplace=True)
skill_penetration
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16824 entries, 0 to 16823
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   year                          16824 non-null  int64
#  1   isic_section_index            16824 non-null  object
#  2   isic_section_name             16824 non-null  object
#  3   industry_name                 16824 non-null  object
#  4   skill_group_category          16824 non-null  object
#  5   skill_group_name              16824 non-null  object
#  6   skill_group_penetration_rate  16824 non-null  float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 920.2+ KB
#                   year  ... skill_group_penetration_rate
# skill_group_name        ...
# Accounts Payable  2015  ...                      0.00658
# Accounts Payable  2015  ...                      0.00213
# Accounts Payable  2015  ...                      0.00203
# ...

# %%
AI = skill_penetration.loc['Artificial Intelligence']
AI
# Out:
#                          year  ... skill_group_penetration_rate
# skill_group_name               ...
# Artificial Intelligence  2015  ...                      0.00048
# Artificial Intelligence  2015  ...                      0.00035
# Artificial Intelligence  2015  ...                      0.00028
# Artificial Intelligence  2015  ...                      0.00021
# Artificial Intelligence  2015  ...                      0.00019
# Artificial Intelligence  2015  ...                      0.00017
# Artificial Intelligence  2015  ...                      0.00016
# Artificial Intelligence  2015  ...                      0.00015
# Artificial Intelligence  2015  ...                      0.00011
# Artificial Intelligence  2015  ...                      0.00011
# Artificial Intelligence  2015  ...                      0.00010
# Artificial Intelligence  2016  ...                      0.00116
# Artificial Intelligence  2016  ...                      0.00090
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
B2= AI[['year','industry_name','skill_group_penetration_rate']]

# %%
B2
# Out:
#                          year  ... skill_group_penetration_rate
# skill_group_name               ...
# Artificial Intelligence  2015  ...                      0.00048
# Artificial Intelligence  2015  ...                      0.00035
# Artificial Intelligence  2015  ...                      0.00028
# Artificial Intelligence  2015  ...                      0.00021
# Artificial Intelligence  2015  ...                      0.00019
# Artificial Intelligence  2015  ...                      0.00017
# Artificial Intelligence  2015  ...                      0.00016
# Artificial Intelligence  2015  ...                      0.00015
# Artificial Intelligence  2015  ...                      0.00011
# Artificial Intelligence  2015  ...                      0.00011
# Artificial Intelligence  2015  ...                      0.00010
# Artificial Intelligence  2016  ...                      0.00116
# Artificial Intelligence  2016  ...                      0.00090
# ...

# %%
plt.plot(B2.year, B2.skill_group_penetration_rate)

plt.title('Skill penetration trend over the years 2015 - 2018')
plt.xlabel('years')
plt.ylabel('skill_group_penetration_rate')
# Out:
# Text(0, 0.5, 'skill_group_penetration_rate')

# %%
Industry_name= B2.groupby('industry_name')
Industry_name
for year,year_B2 in Industry_name:

  print(year)
  print(year_B2)
# Out:
# Biotechnology
#                          year  industry_name  skill_group_penetration_rate
# skill_group_name
# Artificial Intelligence  2015  Biotechnology                       0.00010
# Artificial Intelligence  2016  Biotechnology                       0.00023
# Artificial Intelligence  2017  Biotechnology                       0.00060
# Artificial Intelligence  2018  Biotechnology                       0.00093
# Computer & Network Security
#                          year  ... skill_group_penetration_rate
# skill_group_name               ...
# Artificial Intelligence  2015  ...                      0.00011
# Artificial Intelligence  2016  ...                      0.00024
# Artificial Intelligence  2017  ...                      0.00049
# Artificial Intelligence  2018  ...                      0.00101
#
# [4 rows x 3 columns]
# Computer Games
#                          year   industry_name  skill_group_penetration_rate
# skill_group_name
# ...

# %%
Industry_name.max()
# Out:
#                                    year  skill_group_penetration_rate
# industry_name
# Biotechnology                      2018                       0.00093
# Computer & Network Security        2018                       0.00101
# Computer Games                     2018                       0.00099
# Computer Networking                2018                       0.00081
# Computer Software                  2018                       0.00499
# Information Services               2018                       0.00174
# Information Technology & Services  2018                       0.00229
# Internet                           2018                       0.00221
# Investment Management              2018                       0.00123
# Research                           2018                       0.00369
# Semiconductors                     2018                       0.00235

# %%
Biotechnology= Industry_name.get_group('Biotechnology')
Biotechnology
# Out:
#                          year  skill_group_penetration_rate
# skill_group_name
# Artificial Intelligence  2015                       0.00010
# Artificial Intelligence  2016                       0.00023
# Artificial Intelligence  2017                       0.00060
# Artificial Intelligence  2018                       0.00093

# %%
plt.plot(Biotechnology.year,Biotechnology.skill_group_penetration_rate)
plt.title('Skill penetration trend over the years 2015 - 2018 in Biotechnology')
plt.xlabel('years')
plt.ylabel('skill_group_penetration_rate')
# Out:
# Text(0, 0.5, 'skill_group_penetration_rate')

# %%
Computer_software= Industry_name.get_group('Computer Software')
plt.plot(Computer_software.year,Computer_software.skill_group_penetration_rate)
plt.title('Skill penetration trend over the years 2015 - 2018 in Computer software')
plt.xlabel('years')
plt.ylabel('skill_group_penetration_rate')
# Out:
# Text(0, 0.5, 'skill_group_penetration_rate')

# %%
Computer_networking= Industry_name.get_group('Computer Networking')
plt.plot(Computer_networking.year,Computer_networking.skill_group_penetration_rate)
plt.title('Skill penetration trend over the years 2015 - 2018')
plt.xlabel('years')
plt.ylabel('skill_group_penetration_rate')
# Out:
# Text(0, 0.5, 'skill_group_penetration_rate')

# %%
year= B2.groupby('year')
for year, year_B2 in year:

  print(year)
  print(year_B2)
# Out:
# 2015
#                          year  ... skill_group_penetration_rate
# skill_group_name               ...
# Artificial Intelligence  2015  ...                      0.00048
# Artificial Intelligence  2015  ...                      0.00035
# Artificial Intelligence  2015  ...                      0.00028
# Artificial Intelligence  2015  ...                      0.00021
# Artificial Intelligence  2015  ...                      0.00019
# Artificial Intelligence  2015  ...                      0.00017
# Artificial Intelligence  2015  ...                      0.00016
# Artificial Intelligence  2015  ...                      0.00015
# Artificial Intelligence  2015  ...                      0.00011
# Artificial Intelligence  2015  ...                      0.00011
# Artificial Intelligence  2015  ...                      0.00010
#
# [11 rows x 3 columns]
# 2016
#                          year  ... skill_group_penetration_rate
# skill_group_name               ...
# ...

# %%
Industry_name= B2.groupby('industry_name')
for industry_name,industry_name_B2 in Industry_name:

  print(industry_name)
  print(industry_name_B2)
# Out:
# Biotechnology
#                          year  industry_name  skill_group_penetration_rate
# skill_group_name
# Artificial Intelligence  2015  Biotechnology                       0.00010
# Artificial Intelligence  2016  Biotechnology                       0.00023
# Artificial Intelligence  2017  Biotechnology                       0.00060
# Artificial Intelligence  2018  Biotechnology                       0.00093
# Computer & Network Security
#                          year  ... skill_group_penetration_rate
# skill_group_name               ...
# Artificial Intelligence  2015  ...                      0.00011
# Artificial Intelligence  2016  ...                      0.00024
# Artificial Intelligence  2017  ...                      0.00049
# Artificial Intelligence  2018  ...                      0.00101
#
# [4 rows x 3 columns]
# Computer Games
#                          year   industry_name  skill_group_penetration_rate
# skill_group_name
# ...

# %%
Year= B2.groupby('year')
for year,year_B2 in Year:

  print(year)
  print(year_B2)
# Out:
# 2015
#                          year  ... skill_group_penetration_rate
# skill_group_name               ...
# Artificial Intelligence  2015  ...                      0.00048
# Artificial Intelligence  2015  ...                      0.00035
# Artificial Intelligence  2015  ...                      0.00028
# Artificial Intelligence  2015  ...                      0.00021
# Artificial Intelligence  2015  ...                      0.00019
# Artificial Intelligence  2015  ...                      0.00017
# Artificial Intelligence  2015  ...                      0.00016
# Artificial Intelligence  2015  ...                      0.00015
# Artificial Intelligence  2015  ...                      0.00011
# Artificial Intelligence  2015  ...                      0.00011
# Artificial Intelligence  2015  ...                      0.00010
#
# [11 rows x 3 columns]
# 2016
#                          year  ... skill_group_penetration_rate
# skill_group_name               ...
# ...

# %%
Year= B2.groupby('year',observed = False, )
for year,year_B2 in Year:

  print(year)
  print(year_B2)
# Out:
# 2015
#                          year  ... skill_group_penetration_rate
# skill_group_name               ...
# Artificial Intelligence  2015  ...                      0.00048
# Artificial Intelligence  2015  ...                      0.00035
# Artificial Intelligence  2015  ...                      0.00028
# Artificial Intelligence  2015  ...                      0.00021
# Artificial Intelligence  2015  ...                      0.00019
# Artificial Intelligence  2015  ...                      0.00017
# Artificial Intelligence  2015  ...                      0.00016
# Artificial Intelligence  2015  ...                      0.00015
# Artificial Intelligence  2015  ...                      0.00011
# Artificial Intelligence  2015  ...                      0.00011
# Artificial Intelligence  2015  ...                      0.00010
#
# [11 rows x 3 columns]
# 2016
#                          year  ... skill_group_penetration_rate
# skill_group_name               ...
# ...

# %%
plt.plot('skill_group_penetration_rate', 'year')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-ef7dea877c80> in <module>()
# ----> 1 plt.plot('skill_group_penetration_rate', 'year')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# ...

# %% [markdown]
# #NEW WORK
# To make it keep running: function ClickConnect(){
# console.log("Working");
# document.querySelector("colab-toolbar-button").click()
# }setInterval(ClickConnect,60000)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
B2= AI[['year','industry_name','skill_group_penetration_rate']]

# %%
B2

# %%
Year = B2.groupby(["year"]).agg({"industry_name": "sum", "skill_group_penetration_rate": "sum"})
Year

# %%
Year.plot()

# %%
Z = B2.groupby('year')
for year, year_B2 in Z:

  print(year)
  print(year_B2)

# %%
AI = skill_penetration.loc['Artificial Intelligence']
AI

# %%
#A2=B2

# %%
A2= AI[['year','industry_name','skill_group_penetration_rate']]
A2

# %%
Year= A2.groupby('year',), ('industry_name')
Year

# %%
print(Year)

# %%
Industry_name= B2.groupby('industry_name')
for industry_name,industry_name_B2 in Industry_name:

  print(industry_name)
  print(industry_name_B2)

# %%
skill_penetration = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Team 8 project/AI.xlsx', sheet_name='Skill Penetration')

# %%
dd=skill_penetration.copy(deep=True)
dd.set_index('skill_group_name', inplace=True)

# %%
dd.head()

# %%
HG=dd.loc[['Artificial Intelligence']]
HG

# %%
HH=HG.set_index()

# %%
sps_copy= skill_penetration.copy(deep=True)

# %%
sps_copy.mode()

# %%
sps_copy[0:1]

# %%
Skill_group=sps_copy.set_index('skill_group_name', inplace=True)

# %%
sps_copy.head()

# %%
sps2= skill_penetration.copy(deep=True)
sps2

# %%
AI = sps_copy.loc['Artificial Intelligence']
AI

# %%
sps2.info()

# %%
A=sps2[['year','skill_group_name', 'industry_name','skill_group_penetration_rate']]
A

# %%
A2=A.copy(deep= True)
A2

# %%
A2.head()
A2

# %%
A2.mode()

# %% [markdown]
# Most of the people were working in the oil and energy industry, most of the skills group had a penetration of 0.00021(0.021%),most people were in the Business management skill group,

# %%
A2.set_index('skill_group_name', inplace=True)

# %%
K= A2.loc[['Artificial Intelligence']]
K

# %%
K.max()

# %%
K.min()

# %%
k6=K.copy(deep=True)
k6

# %%
k6.reset_index(inplace =True)
k6

# %%
k7=k6.copy(deep=True)
k7

# %%
k7.set_index('year', inplace=True)

# %%
k5=k7.loc[[2015]]
k5

# %%
k5.set_index('industry_name', inplace=True)

# %%
k5.plot(kind='barh')
plt.xlabel('skill group penetration rate')
plt.title('Penetration rate for the year 2015')

# %%
k8=k7.loc[[2016]]
k8

# %%
k8=k7.loc[[2016]]
k8.set_index('industry_name', inplace=True)
k8.plot(kind='barh')
plt.xlabel('skill group penetration rate')
plt.title('Penetration rate for the year 2016')

# %%
k9=k7.loc[[2017]]
k9.set_index('industry_name', inplace=True)
k8.plot(kind='barh')
plt.xlabel('skill group penetration rate')
plt.title('Penetration rate for the year 2017')

# %%
k10=k7.loc[[2017]]
k10.set_index('industry_name', inplace=True)
k8.plot(kind='barh')
plt.xlabel('skill group penetration rate')
plt.title('Penetration rate for the year 2018')

# %%
pd.crosstab(index= k6['skill_group_penetration_rate'],columns=k6['industry_name'])

# %%
k6.set_index('industry_name',inplace =True)

# %%
k6.plot(kind='bar')

# %%
pd.crosstab(index= k6['What is your gender'],columns=df_job['Unemployed or employed'])

# %%
A

# %%
pd.crosstab(index= sps2['skill_group_name'],columns=sps2['skill_group_penetration_rate'])

# %% [markdown]
# #working on ISS

# %%
industry_skills = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Team 8 project/AI.xlsx', sheet_name='Industry Skills Needs')

# %%
growth = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Team 8 project/AI.xlsx', sheet_name='Growth')
growth.head()

# %%
copy_g=growth.copy(deep=True)
copy_g

# %%
copy_g.mode()

# %% [markdown]
# #Most are in the computer software industry and growth has been reduced over the years

# %%
copy_g.describe()

# %%
copy_g.info()

# %%
WD= copy_g[['country_name','wb_income','isic_section_name','industry_name','growth_rate_2015','growth_rate_2016','growth_rate_2017','growth_rate_2018']]
WD

# %%
WG=WD.copy(deep=True)
WG

# %%
WG.set_index('industry_name', inplace=True)

# %%
print(WG)

# %%
WG.head()

# %%
SD= WG.loc[['Computer Software']]
SD

# %%
SD.reset_index(inplace=True)

# %%
SD

# %%
SD.head()

# %%
k7.set_index('isic_section_name', inplace=True)

# %% [markdown]
# #new 2

# %%
LT=skill_penetration.copy(deep=True)
LT.head()
# Out:
#                   year  ... skill_group_penetration_rate
# skill_group_name        ...
# Accounts Payable  2015  ...                      0.00658
# Accounts Payable  2015  ...                      0.00213
# Accounts Payable  2015  ...                      0.00203
# Accounts Payable  2015  ...                      0.00136
# Accounts Payable  2015  ...                      0.00123
#
# [5 rows x 6 columns]

# %%
ST=LT.loc[['Artificial Intelligence']]
ST
# Out:
#                          year  ... skill_group_penetration_rate
# skill_group_name               ...
# Artificial Intelligence  2015  ...                      0.00048
# Artificial Intelligence  2015  ...                      0.00035
# Artificial Intelligence  2015  ...                      0.00028
# Artificial Intelligence  2015  ...                      0.00021
# Artificial Intelligence  2015  ...                      0.00019
# Artificial Intelligence  2015  ...                      0.00017
# Artificial Intelligence  2015  ...                      0.00016
# Artificial Intelligence  2015  ...                      0.00015
# Artificial Intelligence  2015  ...                      0.00011
# Artificial Intelligence  2015  ...                      0.00011
# Artificial Intelligence  2015  ...                      0.00010
# Artificial Intelligence  2016  ...                      0.00116
# Artificial Intelligence  2016  ...                      0.00090
# ...

# %%
ST.reset_index(inplace =True)

# %%
ST.set_index('year', inplace=True)

# %%
ST.head()
# Out:
#              skill_group_name  ... skill_group_penetration_rate
# year                           ...
# 2015  Artificial Intelligence  ...                      0.00048
# 2015  Artificial Intelligence  ...                      0.00035
# 2015  Artificial Intelligence  ...                      0.00028
# 2015  Artificial Intelligence  ...                      0.00021
# 2015  Artificial Intelligence  ...                      0.00019
#
# [5 rows x 6 columns]

# %%
ST.plot(kind='barh')
plt.xlabel('skill group penetration rate')
plt.title('AI Penetration rate trend for the years 2015-2018')
# Out:
# Text(0.5, 1.0, 'AI Penetration rate trend for the years 2015-2018')

# %%
ST.plot(kind='bar')
plt.ylabel('skill group penetration rate')
plt.title('AI Penetration rate trend for the years 2015-2018')
# Out:
# Text(0.5, 1.0, 'AI Penetration rate trend for the years 2015-2018')

# %%
copy_Gr2=growth.copy(deep=True)
copy_Gr2.head()
# Out:
#   country_code          country_name  ... growth_rate_2017 growth_rate_2018
# 0           ae  United Arab Emirates  ...         0.039914         0.001594
# 1           ae  United Arab Emirates  ...         0.005206         0.006746
# 2           ae  United Arab Emirates  ...         0.071920         0.029334
# 3           ae  United Arab Emirates  ...         0.010805         0.001697
# 4           ae  United Arab Emirates  ...         0.043913         0.024524
#
# [5 rows x 12 columns]

# %%
copy_Gr2.set_index('isic_section_name', inplace =True)

# %%
copy_Gr2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7198 entries, Mining and quarrying to Arts, entertainment and recreation
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country_code        7198 non-null   object
#  1   country_name        7198 non-null   object
#  2   wb_region           7198 non-null   object
#  3   wb_income           7198 non-null   object
#  4   isic_section_index  7198 non-null   object
#  5   industry_id         7198 non-null   int64
#  6   industry_name       7198 non-null   object
#  7   growth_rate_2015    7198 non-null   float64
#  8   growth_rate_2016    7198 non-null   float64
#  9   growth_rate_2017    7198 non-null   float64
#  10  growth_rate_2018    7198 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 674.8+ KB

# %%
copy_Gr2.head()
# Out:
#                      country_code  ... growth_rate_2018
# isic_section_name                  ...
# Mining and quarrying           ae  ...         0.001594
# Mining and quarrying           ae  ...         0.006746
# Manufacturing                  ae  ...         0.029334
# Manufacturing                  ae  ...         0.001697
# Manufacturing                  ae  ...         0.024524
#
# [5 rows x 11 columns]

# %%
KY = copy_Gr2.loc[['Information and communication']]
KY
# Out:
#                               country_code  ... growth_rate_2018
# isic_section_name                           ...
# Information and communication           ae  ...        -0.001103
# Information and communication           ae  ...         0.066265
# Information and communication           ae  ...         0.031863
# Information and communication           ae  ...         0.063825
# Information and communication           ae  ...         0.021053
# ...                                    ...  ...              ...
# Information and communication           zw  ...        -0.007435
# Information and communication           zw  ...        -0.004484
# Information and communication           zw  ...         0.000000
# Information and communication           zw  ...        -0.014094
# Information and communication           zw  ...        -0.005747
#
# [1589 rows x 11 columns]

# %%
SD=KY.set_index('wb_income', inplace =True)

# %%
BG=KY.loc[['High income']]
BG
# Out:
#             country_code  ... growth_rate_2018
# wb_income                 ...
# High income           ae  ...        -0.001103
# High income           ae  ...         0.066265
# High income           ae  ...         0.031863
# High income           ae  ...         0.063825
# High income           ae  ...         0.021053
# ...                  ...  ...              ...
# High income           uy  ...        -0.021505
# High income           uy  ...         0.001891
# High income           uy  ...         0.077778
# High income           uy  ...        -0.045455
# High income           uy  ...        -0.036649
#
# [731 rows x 10 columns]

# %%
KL=BG[['industry_name','growth_rate_2015','growth_rate_2016','growth_rate_2017','growth_rate_2018']]
KL
# Out:
#                                  industry_name  ...  growth_rate_2018
# wb_income                                       ...
# High income                  Computer Hardware  ...         -0.001103
# High income                  Computer Software  ...          0.066265
# High income                Computer Networking  ...          0.031863
# High income                           Internet  ...          0.063825
# High income                     Semiconductors  ...          0.021053
# ...                                        ...  ...               ...
# High income                         Publishing  ...         -0.021505
# High income  Information Technology & Services  ...          0.001891
# High income                     Computer Games  ...          0.077778
# High income                       Online Media  ...         -0.045455
# High income                   Media Production  ...         -0.036649
#
# [731 rows x 5 columns]

# %%
KL.set_index('industry_name', inplace=True)

# %%
KL.plot(kind='line')
plt.xticks(rotation =90)
# Out:
# (array([-100.,    0.,  100.,  200.,  300.,  400.,  500.,  600.,  700.,
#          800.]), <a list of 10 Text major ticklabel objects>)

# %%
#FF69B4

# %%
KL.plot(kind='line')
plt.xticks(rotation =90)
colour = 'FF69B4'

# %%
KL.describe()
# Out:
#        growth_rate_2015  growth_rate_2016  growth_rate_2017  growth_rate_2018
# count        731.000000        731.000000        731.000000        731.000000
# mean           0.018288          0.016094          0.010322          0.006052
# std            0.061817          0.054299          0.044412          0.033584
# min           -0.206478         -0.287554         -0.269880         -0.176471
# 25%           -0.016495         -0.012749         -0.014189         -0.012273
# 50%            0.009794          0.007075          0.004761          0.002336
# 75%            0.041768          0.036509          0.028422          0.022650
# max            0.337950          0.321429          0.260870          0.158879

# %%
import seaborn as sns

# %%
sns.lineplot(data=KL, x='industry_name', hue='block')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-4b96206f6f6d> in <module>()
# ----> 1 sns.lineplot(data=KL, x='industry_name', hue='block')
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     693         data=data, variables=variables,
#     694         estimator=estimator, ci=ci, n_boot=n_boot, seed=seed,
# ...

# %%
KL.plot(kind='line')
plt.xticks(rotation =90)
colour = 'FF69B4'

# %%
BG.plot(kind='line')

# %%
KY.head()

# %%
KY.plot(kind='bar')

# %%
xaxis.set_major_locator(plt.MaxNLocator(3))

# %%
ST.plot(kind='bar')
plt.ylabel('skill group penetration rate')
ST.xaxis.set_major_locator(plt.MaxNLocator(4))
plt.title('AI Penetration rate trend for the years 2015-2018')

# %%
ST.plot(kind='bar')
plt.ylabel('skill group penetration rate')
plt.xlabel(rotate=90)
plt.title('AI Penetration rate trend for the years 2015-2018')

# %%
ST.plot(kind='bar')
plt.ylabel('skill group penetration rate')
plt.xticks(rotation=90, fontsize=15)
plt.xticks(set_major_locator(4))
plt.title('AI Penetration rate trend for the years 2015-2018')

# %%
ST.plot(kind='bar')
plt.ylabel('skill group penetration rate')
plt.xticks(rotation=90, fontsize=15)
ST.locator_params(nbins=4, axis='y')
plt.title('AI Penetration rate trend for the years 2015-2018')

# %%
ax.locator_params(nbins=4, axis='y')

# %%
ST.plot(kind='bar')
plt.ylabel('skill group penetration rate')
plt.xlabel.MaxNLocator(4))
plt.title('AI Penetration rate trend for the years 2015-2018')

# %%
ST.plot(kind='line')
plt.xlabel('skill group penetration rate')
plt.title('AI Penetration rate trend for the years 2015-2018')
